# %% [markdown]
# # Please check these prerequisites

# %%
# !pip install --upgrade pandas==1.3.5 openpyxl==3.0.10 numpy==1.21.6 geopandas==0.10 altair==4.2.0 watermark==2.3.1 gpdvega matplotlib==3.5 wordcloud==1.8.2.2 tqdm==4.64.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
# ...
#   Using cached watermark-2.3.1-py2.py3-none-any.whl (7.2 kB)
# ...
#   Using cached gpdvega-0.1.1rc1-py3-none-any.whl (3.4 kB)
# ...
#      |████████████████████████████████| 11.2 MB 3.8 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 41.0 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 704 kB/s
# ...
#      |████████████████████████████████| 42 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 960 kB 56.4 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 53.0 MB/s
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ...
